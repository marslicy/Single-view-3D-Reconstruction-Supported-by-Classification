# %%
from model.inference import Inference
import torch
from data.shapenet import ShapeNetDataset
from data.shapenet_loader import ShapeNetDataLoader
from util.visualization import visualize_3d, visualize_2d

# %%
infer = Inference('./runs/07-26-21-39-cat_same_a0.05b1/val_shape_model_best.ckpt', torch.device('cpu'))

test_dataset_shape = ShapeNetDataset(
        "shape_test", 1, 1
    )
test_dataloader_shape = ShapeNetDataLoader(
    test_dataset_shape,  # Datasets return data one sample at a time; Dataloaders use them and aggregate samples into batches
    batch_size=16,  # The size of batches is defined here
    shuffle=True,
)
for batch_idx, batch in enumerate(test_dataloader_shape):
    # Move batch to device
    x1 = batch["class"]
    x2 = batch["encoder"]
    y1 = batch["GT"]
    y2 = batch["3D"]
    pred_class, pred_3d = infer.reconstruct(batch['class'].float(), batch['class'].float())
    break

# %%
visualize_3d(pred_3d[1], y2[1], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[1])

# %%
visualize_3d(pred_3d[2], y2[2], 'test')
# Out:
# Output()

# %%
visualize_3d(pred_3d[6], y2[6], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[6])

# %%
visualize_3d(pred_3d[5], y2[5], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[5])

# %%
visualize_3d(pred_3d[3], y2[3], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[3])

# %%
visualize_3d(pred_3d[0], y2[0], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[0])

# %%
visualize_3d(pred_3d[10], y2[10], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[10])

# %%
visualize_3d(pred_3d[9], y2[9], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[9])

# %%
visualize_3d(pred_3d[7], y2[7], 'test')
# Out:
# Output()

# %%
visualize_2d(x1[7])
